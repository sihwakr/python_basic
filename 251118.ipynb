# %% [markdown]
# ## Print 함수

# %%
print("hello World")
# Out:
# hello World

# %%
print("Hello" + " " + "word")
'''
파이썬에서 +는 연결을 한다
1. 숫자형에서의 산술 덧셈
2. 문자열에서의 문자열 연결 
3. 리스트 튜플 시퀀스에서 시퀀스 합치기
'''
# Out:
# Hello word
# '\n파이썬에서 +는 연결을 한다\n1. 숫자형에서의 산술 덧셈\n2. 문자열에서의 문자열 연결 \n3. 리스트 튜플 시퀀스에서 시퀀스 합치기\n'

# %%
print({'name':'Joon','age':38})
# Out:
# {'name': 'Joon', 'age': 38}

# %%
print([1,2,3])
# Out:
# [1, 2, 3]

# %%
print((1,2,3))
# Out:
# (1, 2, 3)

# %%
print(42)
print(3.14)
print(False)
# Out:
# 42
# 3.14
# False

# %%
print('home','user','document',sep='/')
# Out:
# home/user/document

# %% [markdown]
# ## input 함수

# %%
print(input('What is uyour age?'))
# Out:
# 17

# %%
print("My name is " + input("How are you? What is your name?"))
# Out:
# My name is sihwa

# %%
print(len(input("What is your name?")))
# Out:
# 5

# %% [markdown]
# ## Variable 변수

# %%
name = input("What is your name?")

# %%
print('Here is my name,' + name)
# Out:
# Here is my name,sihwa

# %%
name = 'sihwa'
print(name)
# Out:
# sihwa

# %%
x, y =1,2 
#콤마를 사용해서 어사인 할 수 도 있다

# %%
print(x)
print(y)
# Out:
# 1
# 2

# %%
x=y=1
#오른쪽 부터 실행됨 y=1 / x=1 이렇게 리턴

# %%
print(x)
print(y)
# Out:
# 1
# 1

# %% [markdown]
# ## concateration
# 여러 조각을 하나로 이어 붙이는 것
# "A" + "B" = "AB"
# 문자열이면 문자열끼리, 리스트면 리스트끼리 “붙인다(concatenate)”는 의미야.

# %%
print(1+2)
#int+int =int
# Out:
# 3

# %%
print(1+1.5)
#int+flot=flot
# Out:
# 2.5

# %%
print("Hello"+"World")
#str+str=str
# Out:
# HelloWorld
