# %% [markdown]
# ## [인터뷰 예제] 문자열 뒤집기

# %%
value = 'Hello World'

# %%
#reverse
value_list = list(value)
value_list.reverse()
print("".join(value_list))
# Out:
# dlroW olleH

# %%
print("".join(list(reversed(value))))
# Out:
# dlroW olleH

# %%
temp_list = []
for i in range(len(value)-1, -1, -1):
    temp_list.append(value[i])
print("".join(temp_list))
# Out:
# dlroW olleH

# %%
value = 'Hello World'
value_list = list(value)
temp_list=[]
while len(value_list)>0:
    temp_list.append(value_list.pop())
print("".join(temp_list))
# Out:
# dlroW olleH

# %% [markdown]
# ## 파라미터를 받는 함수에 대해 알아보기

# %%
def travel():
    print("Hello ther")
    print("Are you exited?")

travel()
# Out:
# Hello ther
# Are you exited?

# %%
def travle_to_country(country: str):
    print(f"You are going to travel to {country}")
    print("Are you exited?")

travle_to_country('korea')
# country => parameter
# "korea" => argument
# Out:
# You are going to travel to korea
# Are you exited?

# %%
def travel_to_country(country:str,name:str):
    print(f"Hello {name}!")
    print(f"you are going to travle to {country}")
    print("Are you exited?")
# positional argument
travel_to_country("korea", "sihwa")
# Out:
# Hello sihwa!
# you are going to travle to korea
# Are you exited?

# %%
# keyword argument
travel_to_country(country="korea", name="sihwa")
# Out:
# Hello sihwa!
# you are going to travle to korea
# Are you exited?

# %% [markdown]
# ## 함수의 리턴 값에 대해 알아보기

# %%
def get_name(first_name, last_name):
    if first_name == "":
        return "Your first name is missing ..."
    if last_name == "":
        return "Your last name is missing ..."
    return f"{first_name}, {last_name}"

return_value = get_name(
    first_name=input("Your first name?"),
    last_name=input("Your last name?"))

print(return_value)
# Out:
# 백, 시관

# %%
score = 10

def update_score():
    internal_score = score
    internal_score = 20

    return internal_score  # 20을 밖으로 던짐

print(score)
# Out:
# 10

# %%
score = 10

def update_score():
    score = 20
    return score  # 20을 밖으로 던짐

print(score)
# Out:
# 10

# %%
# [1] 내 통장 잔고 (전역 변수) -> 서울 사는 진짜 돈
my_balance = 0

# [2] 입금 함수 (기능)
def deposit(balance, amount):
    print(f"💰 {amount}원을 입금합니다.")
    return balance + amount  # 계산된 새 잔고를 밖으로 던짐!

# [3] 출금 함수 (기능)
def withdraw(balance, amount):
    if balance < amount:
        print("이런.. 잔액이 부족해요!")
        return balance # 돈이 안 빠져나갔으니 그대로 던짐
    
    print(f"💸 {amount}원을 출금합니다.")
    return balance - amount # 뺀 값을 던짐

# --- 실행 (Main) ---

print(f"현재 잔고: {my_balance}")

# 1. 10,000원 입금
# 함수가 던진 값을 받아서 my_balance를 갱신! (덮어쓰기)
my_balance = deposit(my_balance, 10000) 
print(f"갱신된 잔고: {my_balance}")

# 2. 3,000원 출금
my_balance = withdraw(my_balance, 3000)
print(f"갱신된 잔고: {my_balance}")

# 3. 20,000원 출금 시도 (잔액 부족)
my_balance = withdraw(my_balance, 20000)
print(f"최종 잔고: {my_balance}")
# Out:
# 현재 잔고: 0
# 💰 10000원을 입금합니다.
# 갱신된 잔고: 10000
# 💸 3000원을 출금합니다.
# 갱신된 잔고: 7000
# 이런.. 잔액이 부족해요!
# 최종 잔고: 7000

# %% [markdown]
# ## [초미니 프로젝트] 더치 페이 함수 만들기

# %%
name_of_ppl = 3
food_price = [10,20,15,17,50]

# %%
def going_dutch(name_of_ppl,food_price):
    k=0
    for i in food_price:
        k= k + i
    fianl_price = k / name_of_ppl
    return fianl_price

answer = going_dutch(name_of_ppl,food_price)
print(answer)
# Out:
# 37.333333333333336

# %% [markdown]
# ## [인터뷰 예제] 소수(Prime number) 찾기

# %%
# Prime number
# https://en.wikipedia.org/wiki/Prime_number
# A prime number (or a prime) is a natural number greater than 1 that is not a product of two smaller natural numbers

# %%
def find_prime_nuber(is_this_prime_number):
    value = True

    for i in range(2,is_this_prime_number):
        if is_this_prime_number%i ==0:
            value = False
            break
    if value:
        print(f"{is_this_prime_number}는 소수입니다")
    else:
        print(f"{is_this_prime_number}는 소수가 아닙니다")

# %%
find_prime_nuber(10)
# Out:
# 10는 소수가 아닙니다

# %%
is_this_prime_number = 4

def is_prime_number(num: int):
    if num > 1:
        is_divisible = False
        for n in range(2, num):
            if num % n == 0:
                print(f"{num} can be cleanly divided by {n}")
                is_divisible = True
                break
        if is_divisible:
             print("Snap! it is not the prime number")
        else:
            print(f"Congrat! {num} is a prime number")
    else:
        print(f"{num} is not the prime number")

is_prime_number(num=is_this_prime_number)
# Out:
# 4 can be cleanly divided by 2
# Snap! it is not the prime number

# %% [markdown]
# ## Dictionary data structure(딕셔너리 자료구조)에 대해 알아보기

# %%
# dictionaries
# key value

# %%
dic = {
    "country" : "South korea",
    "city" : "seoul",
    "gender" : "male",
    "age" : 30
}

print(dic["country"])
# Out:
# South korea

# %%
for key, value in dic.items():
    print(f"{key}:{value}")
# Out:
# country:South korea
# city:seoul
# gender:male
# age:30

# %%
for key in dic:
        print(f"{key}:{dic[key]}")
# Out:
# country:South korea
# city:seoul
# gender:male
# age:30

# %%
print(dic.keys())
# Out:
# dict_keys(['country', 'city', 'gender', 'age'])

# %%
print(dic.values())
# Out:
# dict_values(['South korea', 'seoul', 'male', 30])

# %%
#key error
print(dic["name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 2
#       1 #key error
# ----> 2 print(dic["name"])
#
# KeyError: 'name'

# %%
print("name" in dic)
# Out:
# False

# %%
dic1 = {
    1:1,
    2:2
}
print(dic1[2])
# Out:
# 2

# %%
# Grading program
# grading A if >= 90, B if >= 80, C if >= 70 otherwise F
students = {
    "tom": 82,
    "jerry": 93,
    "joon": 99,
    "misha": 80,
    "amy": 74
}

for key,value in students.items():
    if value >= 90:
        print(f"{key} 는 A등급입니다")
    elif value>=80 and value < 90:
        print(f"{key} 는 B등급입니다")
    elif value>=70 and value < 80:
        print(f"{key} 는 C등급입니다")
    else:
        print(f"{key} 는 F등급입니다")
# Out:
# tom 는 B등급입니다
# jerry 는 A등급입니다
# joon 는 A등급입니다
# misha 는 B등급입니다
# amy 는 C등급입니다

# %%
# Grading program
# grading A if >= 90, B if >= 80, C if >= 70 otherwise F
students = {
    "tom": 82,
    "jerry": 93,
    "joon": 99,
    "misha": 80,
    "amy": 74
}

def get_grade(score: int):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    else:
        return 'F'
for name, score in students.items():
    print(f"{name}'s score is {score}")
    print(f"then, {get_grade(score=score)}")
# Out:
# tom's score is 82
# then, B
# jerry's score is 93
# then, A
# joon's score is 99
# then, A
# misha's score is 80
# then, B
# amy's score is 74
# then, C

# %% [markdown]
# ## Nested data structure(복합 데이타 구조)에 대해서 알아보기

# %%
# Nesting
# dictionaries {"key": "value"}
# list ["a", "b", "c"]

# %%
usa = {
    "name" : "USA",
    "continent" : "North America"
}

south_korea = {
    "name": "South korea",
    "continent" : "East Asia" 
}

countries = [
    usa,
    south_korea
]

# %%
countries
# Out:
# [{'name': 'USA', 'continent': 'North America'},
#  {'name': 'South korea', 'continent': 'East Asia'}]

# %%
for country in countries:
    print(country)
    print(country['name'])
# Out:
# {'name': 'USA', 'continent': 'North America'}
# USA
# {'name': 'South korea', 'continent': 'East Asia'}
# South korea

# %%
california = ["los angeles", "san francisco"]
us_state = [california,"washington","oregon"]

print(us_state)
# Out:
# [['los angeles', 'san francisco'], 'washington', 'oregon']

# %%
countries = [
    us_state,
    south_korea
]
countries
# Out:
# [[['los angeles', 'san francisco'], 'washington', 'oregon'],
#  {'name': 'South korea', 'continent': 'East Asia'}]

# %% [markdown]
# ## Assignment vs. Shallow Copy vs. Deep Copy

# %%
# # Assignement Operator(=)
# # Assignment with an = on lists does not make a copy. Instead, assignment makes the two variables point to the one list in memory.

# %%
colors = ['red ', 'blue','green']
b= colors
b.append("white")
print(b)
print(colors)
# Out:
# ['red ', 'blue', 'green', 'white']
# ['red ', 'blue', 'green', 'white']

# %%
# # Shallow Copy
# # A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.

# %%
a = [[1,2],[2,4]]
b = a[:]
b.append([3,6])
print(b)
print(a)
# Out:
# [[1, 2], [2, 4], [3, 6]]
# [[1, 2], [2, 4]]

# %%
b[0].append(3)
print(b)
print(a)
# Out:
# [[1, 2, 3], [2, 4], [3, 6]]
# [[1, 2, 3], [2, 4]]

# %%
# # Deep Copy
# # A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.

# %%
a=[[1,2],[2,4]]
import copy
b=copy.deepcopy(a)
b[0].append(4)
print(b)
print(a)
# Out:
# [[1, 2, 4], [2, 4]]
# [[1, 2], [2, 4]]

# %%
# # simple list

# %%
a = [1,2,3,4]
b = a[:]
b.append(5)
print(b)
print(a)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4]
