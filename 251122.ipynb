# %% [markdown]
# ## Mathmatical operation(수학 연산자)에 대해서 알아보기

# %%
print(3+1)
# Out:
# 4

# %%
print(3-1)
# Out:
# 2

# %%
print(3*1)
# Out:
# 3

# %%
print(3/2)
#정수 int를 넣어도 float으로 리턴된다
# Out:
# 1.5

# %%
#floor division(몫만 나오는거)
print(7//2)
# Out:
# 3

# %%
#Exponents 지수
#수학에서 말하는 그 aⁿ(에이의 엔제곱) 할 때의 “지수”!
print(3**4)
# Out:
# 81

# %%
#Modulo(나머지)
print(60%13)
print(12.5%5.5)
# Out:
# 8
# 1.5

# %%
"""
PEMAS(PEMDAS란 계산 순서를 나타내며, 괄호 → 지수 → 곱셈/나눗셈 → 덧셈/뺄셈 순으로, 같은 단계 연산은 왼쪽에서 오른쪽 방향으로 계산하라는 뜻)
Parentheses(괄호)
Exponents(지수)
Multipliction(곱셈)
Division(나눗셈)
Addition(덧셈)
Subtraction(뺄셈)
And Left to Right(그리고 (같은 단계에서는) 왼쪽에서 오른쪽 순서대로)
"""
# Out:
# '\nPEMAS(PEMDAS란 계산 순서를 나타내며, 괄호 → 지수 → 곱셈/나눗셈 → 덧셈/뺄셈 순으로, 같은 단계 연산은 왼쪽에서 오른쪽 방향으로 계산하라는 뜻)\nParentheses(괄호)\nExponents(지수)\nMultipliction(곱셈)\nDivision(나눗셈)\nAddition(덧셈)\nSubtraction(뺄셈)\nAnd Left to Right(그리고 (같은 단계에서는) 왼쪽에서 오른쪽 순서대로)\n'

# %%
sum = 0

# %%
sum +=1 
sum = sum +1
print(sum)
# Out:
# 2

# %% [markdown]
# ## f-string에 대해 알아보기

# %%
#Old age
name = "sihwa"
age = "30"
print("Hello,%s" % name)
print("Hello ,%s , I am %s" % (name,age))

## 만약 너무 길어지면???
# Out:
# Hello,sihwa
# Hello ,sihwa , I am 30

# %%
print("Hello, {}. I am {}.".format(name,age))
# Out:
# Hello, sihwa. I am 30.

# %%
print("Hello, {1}. I am {0}.".format(name,age))
# Out:
# Hello, 30. I am sihwa.

# %%
person = {'name' : 'sihwa', 'age' : 20}
print("Hello,{name}. I am {age}".format(name=person['name'],age =person['age']))
# Out:
# Hello,sihwa. I am 20

# %%
print("Hello,{name}. I am{age}.".format(**person))
# Out:
# Hello,sihwa. I am20.

# %%
print(f"Hello,{name}. I am{age}")
print(F"Hello,{name}. I am{age}")
print(f"{name.lower()} is cool")
# Out:
# Hello,sihwa. I am30
# Hello,sihwa. I am30
# sihwa is cool
