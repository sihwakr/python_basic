# %% [markdown]
# ## Primitive data type(원시 자료형)

# %%
#Integer
profile_number = 2030
print(profile_number)
# Out:
# 2030

# %%
#Floats(Decical Point)
score = float(59)
print(score)
# Out:
# 59.0

# %%
#Boolean(True or False)
is_correct = True

# %%
#String(str)
teacher_name = "Cisca"
course_name='CSC'
lecture_name="""
Cisca
Oladipo
"""

# %%
print(lecture_name)
# Out:
# Cisca
# Oladipo

# %%
#String subscript
#문자열의 특정 위치(인덱스)에 있는 글자를 가져오는 것

# %%
print(teacher_name[1])
print(teacher_name[len(teacher_name)-1])
# Out:
# i
# a

# %%
#check object type
print(type(profile_number))
# Out:
# <class 'int'>

# %% [markdown]
# ## Type error(자료형 타입 에러) 처리해 보기

# %%
# str + int

# %%
#print("Hello" + 1 + "world")
#이런식으로 타입이 다르면 오류가 나온다

# %%
#Convert
print(type(1))
# Out:
# <class 'int'>

# %%
print(type(str(1)))
# Out:
# <class 'str'>

# %%
print("Hello"+str(1)+"World")
# Out:
# Hello1World
