# %% [markdown]
# ## Conditional Expression(조건절)에 대해 알아보기

# %%
if 10> 20:
    print(True)
else:
    print(False)
# Out:
# False

# %%
if 10> 20:
    print(True)
elif 3> 6:
    print(False)
else:
    print("False2")
# Out:
# False2

# %%
if int(input("how tall are you in cm?"))>180:
    print("You are over 180")
else:
    print("You are less than 180")
# Out:
# You are less than 180

# %%
# Comparison Operator(비교 연산자)
# > Greater than
# >= Greater than or Equal to
# < Less than
# <= Less than or Equal to
# == Equal to
# != Not equal to

# %% [markdown]
# ## Multiple If Conditional Expression(복합 조건절)에 대해 알아보기

# %%
my_money = 15

# %%
if my_money > 0:
    print(f"my_money,{my_money} is greater than 0")

    if my_money> 10:
        print(f"my_money,{my_money} is also greater than 10")
    if my_money > 20:
        print(f"my_money,{my_money} is also greater than 20")
    else:
        print(f"my_money,{my_money} is less than equal to 20")
# Out:
# my_money,15 is greater than 0
# my_money,15 is also greater than 10
# my_money,15 is less than equal to 20

# %% [markdown]
# ## Logical Operator(논리 연산자)에 대해서 알아보기

# %%
#Logical Operators
#A and B : both Should True
#X or Y : One of them is True
#not E : the opposite value True <-->False

# %%
value = 10

if isinstance(value, int) and value > 5:
    print("Correct")
else:
    print("Not correct")
# Out:
# Correct

# %%
if not isinstance(value,float):
    print(f"{value}is not float")
# Out:
# 10is not float

# %% [markdown]
# ## Randomization(임의) 모듈에 대해서 알아보기

# %%
#ramdom module
import random

# %%
print(random.randint(1,100))
# Out:
# 80

# %%
import sihwa_module

# %%
print(sihwa_module.MY_LOCATION)
# Out:
# KOREA

# %%
random_float = random.random()
print(random_float)
# Out:
# 0.6572252727110176

# %%
## how to generate 0-10??

# %%
print(int(random_float*10))
# Out:
# 6

# %% [markdown]
# ## [초미니 프로젝트] 동전 앞뒤 맞추기

# %%
import random

# %%
random_value = random.randint(0,10)
if random_value % 2 ==0:
    print("You get Head")
else:
    print("you get Tail")
# Out:
# you get Tail

# %%
#내가 만든 버전
random_value = random.randint(1,2)
if random_value ==1:
    print("You get Head")
else:
    print("you get Tail")
# Out:
# you get Tail

# %% [markdown]
# ## List data structure(리스트 자료 구조)에 대해서 알아보기

# %%
#List(Data steucture)
#When to use?
# - Grouping
# Keep the order

countries = ["South Korea","USA","Japan","China"]
print(countries)
# Out:
# ['South Korea', 'USA', 'Japan', 'China']

# %%
countries[2] = "Vietnam"
print(countries)
# Out:
# ['South Korea', 'USA', 'Vietnam', 'China']

# %%
element = "c"
alphabets = ['b',element,'d']
alphabets
# Out:
# ['b', 'c', 'd']

# %%
alphabets.append('e')
alphabets
# Out:
# ['b', 'c', 'd', 'e']

# %%
alphabets += ["f","g"]
alphabets
# Out:
# ['b', 'c', 'd', 'e', 'f', 'g']

# %%
alphabets.insert(0,"a")
alphabets
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
print(countries[0])
print(countries[-1])
print(countries[len(countries)-1])
# Out:
# South Korea
# China
# China

# %%
print(countries.pop())
countries
# Out:
# China
# ['South Korea', 'USA', 'Vietnam']

# %%
print(countries.pop(0))
countries
# Out:
# South Korea
# ['USA', 'Vietnam']

# %%
# please spend your time to look at Python data structure

# %% [markdown]
# ## 리스트 사용시 많이 접하는 Errors 와 nested list(에러와 중첩 리스트)에 대해서 알아보기

# %%
alphabets = ['a','b','c']
print(len(alphabets))
# Out:
# 3

# %%
#print(alphabets[3])
#---------------------------------------------------------------------------
#IndexError                                Traceback (most recent call last)
#Cell In[77], line 1
#----> 1 print(alphabets[3])

#IndexError: list index out of range

# %%
#Nested list
alphabets = [['a','b'],['c']]
print(alphabets)
# Out:
# [['a', 'b'], ['c']]

# %% [markdown]
# ## 반복문 For loop에 대해 알아보기

# %%
#Loop

alphabets=['a','b','c','d']

for alphabet in alphabets:
    print(alphabet)
    print(f"{alphabet} is char")
# Out:
# a
# a is char
# b
# b is char
# c
# c is char
# d
# d is char

# %%
for char in "South Korea":
    print(char)
# Out:
# S
# o
# u
# t
# h
#
# K
# o
# r
# e
# a

# %%
numbers = [1,2,3,4]
sum = 0
for number in numbers:
    sum += number
print(sum/len(numbers))
# Out:
# 2.5

# %%
#max value
numbers = [1,2,3,4]
max_num = 0
for number in numbers:
    if number > max_num:
        max_num = number
print(max_num)
# Out:
# 4

# %%
print(max(numbers))
print(max(1,5))
# Out:
# 4
# 5

# %%
sum = 0
for i in range(1,11):
    sum+=i
sum
# Out:
# 55

# %%
sum = 0
for i in range(1,11):
    if not i % 2 == 0:
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
sum = 0
for i in range(1,11,2):
    sum+=i
sum
# Out:
# 25

# %%
# Given an integer n, return a string array answer (1-indexed) where:

# answer[i] == "FizzBuzz" if i is divisible by 3 and 5.
# answer[i] == "Fizz" if i is divisible by 3.
# answer[i] == "Buzz" if i is divisible by 5.
# answer[i] == i (as a string) if none of the above conditions are true.

# %%
n = int(input())

for i in range(1,n+1):
    if i % 3 ==0 and i % 5==0:
        print("FizzBuzz")
    elif i % 3 ==0:
        print("Fizz")
    elif i % 5 ==0:
        print("buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# buzz
# Fizz
# 7
# 8
# Fizz
# buzz
# 11
# Fizz

# %%
n = 15
answer = []
for i in range(1, n+1):
  if i % 3 == 0 and i % 5 == 0:
    answer.append("FizzBuzz")
  elif i % 3 == 0:
    answer.append("Fizz")
  elif i % 5 == 0:
    answer.append("Buzz")
  else:
    answer.append(str(i))
print(answer)
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']
